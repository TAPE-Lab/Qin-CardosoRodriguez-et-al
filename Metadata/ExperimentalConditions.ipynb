# %% [markdown]
# We should have here a set of tables that identify each of the conditions with a unique identifier.
# Then we can have basic metadata added to each condition (genotype, cell type, treatment,...)
#
# FC: I can start with the scRNAseq and then XQ can do the cytof ones?

# %%
import pandas as pd
import numpy as np

# %%
# import rpy2, rpy2.situation, anndata2ri

# for i in rpy2.situation.iter_info(): # Print Rpy2 info
#     print(i)
# anndata2ri.activate() #This HAS TO be run b4 loading the rpy2 extension
# %load_ext rpy2.ipython

# %%
# data_dir = "~/PhD/S_210125_CRCTME_Jan21/CRCTME_story/Integration_CRCTME-Aug21/RData/"

# %%
# %%R -i data_dir
# library(tidyverse)
# library(Seurat)
# INTepi21 = readRDS(paste0(data_dir,"INTepi21_NOV22.rds"))
# print(levels(INTepi21@meta.data$orig.ident))

# %% [markdown]
# # scRNA-seq
#
# Columns:
#
# * ID
# * Condition
# * Epithelia
# * Genotype
# * Fibroblasts
# * CD34fibroblasts
# * Macrophages
# * WENR
# * Sequencing run /batch

# %%
df = pd.DataFrame(
    [
        ["01_WT_1","monoWT",1,"WT",0,"",0,0,1],
        ["21_WT_2","WTorg_mono",1,"WT",0,"",0,0,2],
        ["02_WT-Mac","cocultWTMac",1,"WT",0,"",1,0,1],
        ["03_WT-Fib","cocultWTFib",1,"WT",1,"unsorted",0,0,1],
        ["24_WT-CD34hi-lo","WTorg_CD34hilo",1,"WT",1,"mix",0,0,2],
        ["22_WT-CD34hi","WTorg_CD34hi",1,"WT",1,"high",0,0,2],
        ["23_WT-CD34lo","WTorg_CD34lo",1,"WT",1,"low",0,0,2],
        ["04_WT-Mac-Fib","cocultWTMacFib",1,"WT",1,"unsorted",1,0,1],
        ["05_A","monoA",1,"A",0,"",0,0,1],
        ["06_A-Mac","cocultAMac",1,"A",0,"",1,0,1],
        ["07_A-Fib","cocultAFib",1,"A",1,"unsorted",0,0,1],
        ["08_A-Mac-Fib","cocultAMacFib",1,"A",1,"unsorted",1,0,1],
        ["09_AK","monoAK",1,"AK",0,"",0,0,1],
        ["10_AK-Mac","cocultAKMac",1,"AK",0,"",1,0,1],
        ["11_AK-Fib","cocultAKFib",1,"AK",1,"unsorted",0,0,1],
        ["12_AK-Mac-Fib","cocultAKMacFib",1,"AK",1,"unsorted",1,0,1],
        ["13_AKP","monoAKP",1,"AKP",0,"",0,0,1],
        ["14_AKP-Mac","cocultAKPMac_REPLICATE",1,"AKP",0,"",1,0,1],
        ["15_AKP-Fib","cocultAKPFib",1,"AKP",1,"unsorted",0,0,1],
        ["16_AKP-Mac-Fib","cocultAKPMacFib",1,"AKP",1,"unsorted",1,0,1],
        ["20_WT-WENR","WTorg_WENR",1,"WT",0,"",0,1,2],
        ["17_Mac","monomac",0,"",0,"",1,0,1],
        ["18_Fib","monoFib",0,"",1,"unsorted",0,0,1],
        ["19_Mac-Fib","cocultMacFib",0,"",1,"unsorted",1,0,1]
    ],
    columns=["ID","orig.ident","Epithelia","Genotype","Fibroblasts","CD34fibroblasts","Macrophages","WENR","Run"])
df
# Out:
#                  ID              orig.ident  Epithelia Genotype  Fibroblasts  \
# 0           01_WT_1                  monoWT          1       WT            0
# 1           21_WT_2              WTorg_mono          1       WT            0
# 2         02_WT-Mac             cocultWTMac          1       WT            0
# 3         03_WT-Fib             cocultWTFib          1       WT            1
# 4   24_WT-CD34hi-lo          WTorg_CD34hilo          1       WT            1
# 5      22_WT-CD34hi            WTorg_CD34hi          1       WT            1
# 6      23_WT-CD34lo            WTorg_CD34lo          1       WT            1
# 7     04_WT-Mac-Fib          cocultWTMacFib          1       WT            1
# 8              05_A                   monoA          1        A            0
# 9          06_A-Mac              cocultAMac          1        A            0
# 10         07_A-Fib              cocultAFib          1        A            1
# 11     08_A-Mac-Fib           cocultAMacFib          1        A            1
# 12            09_AK                  monoAK          1       AK            0
# 13        10_AK-Mac             cocultAKMac          1       AK            0
# 14        11_AK-Fib             cocultAKFib          1       AK            1
# 15    12_AK-Mac-Fib          cocultAKMacFib          1       AK            1
# 16           13_AKP                 monoAKP          1      AKP            0
# 17       14_AKP-Mac  cocultAKPMac_REPLICATE          1      AKP            0
# 18       15_AKP-Fib            cocultAKPFib          1      AKP            1
# 19   16_AKP-Mac-Fib         cocultAKPMacFib          1      AKP            1
# 20       20_WT-WENR              WTorg_WENR          1       WT            0
# 21           17_Mac                 monomac          0                     0
# 22           18_Fib                 monoFib          0                     1
# 23       19_Mac-Fib            cocultMacFib          0                     1
#
#    CD34fibroblasts  Macrophages  WENR  Run
# 0                             0     0    1
# 1                             0     0    2
# 2                             1     0    1
# 3         unsorted            0     0    1
# 4              mix            0     0    2
# 5             high            0     0    2
# 6              low            0     0    2
# 7         unsorted            1     0    1
# 8                             0     0    1
# 9                             1     0    1
# 10        unsorted            0     0    1
# 11        unsorted            1     0    1
# 12                            0     0    1
# 13                            1     0    1
# 14        unsorted            0     0    1
# 15        unsorted            1     0    1
# 16                            0     0    1
# 17                            1     0    1
# 18        unsorted            0     0    1
# 19        unsorted            1     0    1
# 20                            0     1    2
# 21                            1     0    1
# 22        unsorted            0     0    1
# 23        unsorted            1     0    1

# %%
df.to_csv("SampleDF_scRNAseq.csv")

# %% [markdown]
# # Mass Cytometry

# %% [markdown]
# ## WENR Permutation
#
# Metadata columns:
# - batch
# - replicate
# - condition
# - culture
# - format
# - cell-type
# - media
# - W
# - E
# - N
# - R
# - genotype
# - A
# - K
# - P

# %%
df = pd.read_csv("../ZenodoRepo/WENR-Permutation_all-cells.csv.zip")
metadata_columns = [
    "batch",
    "replicate",
    "condition",
    "culture",
    "format",
    "cell-type",
    "media",
    "W",
    "E",
    "N",
    "R",
    "genotype",
    "A",
    "K",
    "P",
]
df_metadata = df.loc[:, metadata_columns]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/ferran/Dropbox (UCL)/TAPE LAB/Manuscripts/Qin & Cardoso Rodriguez et al/SupplementaryMaterials/Qin-CardosoRodriguez-et-al_analysis/Metadata/ExperimentalConditions.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/ferran/Dropbox%20%28UCL%29/TAPE%20LAB/Manuscripts/Qin%20%26%20Cardoso%20Rodriguez%20et%20al/SupplementaryMaterials/Qin-CardosoRodriguez-et-al_analysis/Metadata/ExperimentalConditions.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_csv("../ZenodoRepo/WENR-Permutation_all-cells.csv.zip")
#       <a href='vscode-notebook-cell:/Users/ferran/Dropbox%20%28UCL%29/TAPE%20LAB/Manuscripts/Qin%20%26%20Cardoso%20Rodriguez%20et%20al/SupplementaryMaterials/Qin-CardosoRodriguez-et-al_analysis/Metadata/ExperimentalConditions.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> metadata_columns = [
#       <a href='vscode-notebook-cell:/Users/ferran/Dropbox%20%28UCL%29/TAPE%20LAB/Manuscripts/Qin%20%26%20Cardoso%20Rodriguez%20et%20al/SupplementaryMaterials/Qin-CardosoRodriguez-et-al_analysis/Metadata/ExperimentalConditions.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a>     "batch",
#       <a href='vscode-notebook-cell:/Users/ferran/Dropbox%20%28UCL%29/TAPE%20LAB/Manuscripts/Qin%20%26%20Cardoso%20Rodriguez%20et%20al/SupplementaryMaterials/Qin-CardosoRodriguez-et-al_analysis/Metadata/ExperimentalConditions.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a>     "replicate",
#    (...)
#      <a href='vscode-notebook-cell:/Users/ferran/Dropbox%20%28UCL%29/TAPE%20LAB/Manuscripts/Qin%20%26%20Cardoso%20Rodriguez%20et%20al/SupplementaryMaterials/Qin-CardosoRodriguez-et-al_analysis/Metadata/ExperimentalConditions.ipynb#X14sZmlsZQ%3D%3D?line=16'>17</a>     "P",
#      <a href='vscode-notebook-cell:/Users/ferran/Dropbox%20%28UCL%29/TAPE%20LAB/Manuscripts/Qin%20%26%20Cardoso%20Rodriguez%20et%20al/SupplementaryMaterials/Qin-CardosoRodriguez-et-al_analysis/Metadata/ExperimentalConditions.ipynb#X14sZmlsZQ%3D%3D?line=17'>18</a> ]
#      <a href='vscode-notebook-cell:/Users/ferran/Dropbox%20%28UCL%29/TAPE%20LAB/Manuscripts/Qin%20%26%20Cardoso%20Rodriguez%20et%20al/SupplementaryMaterials/Qin-CardosoRodriguez-et-al_analysis/Metadata/ExperimentalConditions.ipynb#X14sZmlsZQ%3D%3D?line=18'>19</a> df_metadata = df.loc[:, metadata_columns]
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:586, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     571 kwds_defaults = _refine_defaults_read(
#     572     dialect,
#     573     delimiter,
#    (...)
#     582     defaults={"delimiter": ","},
#     583 )
#     584 kwds.update(kwds_defaults)
# --> 586 return _read(filepath_or_buffer, kwds)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:482, in _read(filepath_or_buffer, kwds)
#     479 _validate_names(kwds.get("names", None))
#     481 # Create the parser.
# --> 482 parser = TextFileReader(filepath_or_buffer, **kwds)
#     484 if chunksize or iterator:
#     485     return parser
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:811, in TextFileReader.__init__(self, f, engine, **kwds)
#     808 if "has_index_names" in kwds:
#     809     self.options["has_index_names"] = kwds["has_index_names"]
# --> 811 self._engine = self._make_engine(self.engine)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/readers.py:1040, in TextFileReader._make_engine(self, engine)
#    1036     raise ValueError(
#    1037         f"Unknown engine: {engine} (valid options are {mapping.keys()})"
#    1038     )
#    1039 # error: Too many arguments for "ParserBase"
# -> 1040 return mapping[engine](self.f, **self.options)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/c_parser_wrapper.py:51, in CParserWrapper.__init__(self, src, **kwds)
#      48 kwds["usecols"] = self.usecols
#      50 # open handles
# ---> 51 self._open_handles(src, kwds)
#      52 assert self.handles is not None
#      54 # Have to pass int, would break tests using TextReader directly otherwise :(
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/parsers/base_parser.py:222, in ParserBase._open_handles(self, src, kwds)
#     218 def _open_handles(self, src: FilePathOrBuffer, kwds: dict[str, Any]) -> None:
#     219     """
#     220     Let the readers open IOHandles after they are done with their potential raises.
#     221     """
# --> 222     self.handles = get_handle(
#     223         src,
#     224         "r",
#     225         encoding=kwds.get("encoding", None),
#     226         compression=kwds.get("compression", None),
#     227         memory_map=kwds.get("memory_map", False),
#     228         storage_options=kwds.get("storage_options", None),
#     229         errors=kwds.get("encoding_errors", "strict"),
#     230     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/io/common.py:680, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     678             raise ValueError(f"Zero files found in ZIP file {path_or_buf}")
#     679         else:
# --> 680             raise ValueError(
#     681                 "Multiple files found in ZIP file. "
#     682                 f"Only one file per ZIP: {zip_names}"
#     683             )
#     685 # XZ Compression
#     686 elif compression == "xz":
#
# ValueError: Multiple files found in ZIP file. Only one file per ZIP: ['WENR-Permutation_all-cells.csv', '__MACOSX/._WENR-Permutation_all-cells.csv']

# %%
df_metadata = df_metadata.drop_duplicates(subset=['condition']).sort_values('condition').reset_index(drop=True)
df_metadata.to_csv("SampleDF_MC_WENR.csv")
df_metadata
# Out:
#     batch  replicate         condition     culture       format cell-type  \
# 0      B3          1  A-Fib_Ctrl_Org_1  A-Fib_Ctrl   co-culture       Org
# 1      B3          2  A-Fib_Ctrl_Org_2  A-Fib_Ctrl   co-culture       Org
# 2      B3          3  A-Fib_Ctrl_Org_3  A-Fib_Ctrl   co-culture       Org
# 3      B3          1   A-Fib_ENR_Org_1   A-Fib_ENR   co-culture       Org
# 4      B3          2   A-Fib_ENR_Org_2   A-Fib_ENR   co-culture       Org
# ..    ...        ...               ...         ...          ...       ...
# 355    B2          2      WT_WNR_Org_2      WT_WNR  monoculture       Org
# 356    B2          3      WT_WNR_Org_3      WT_WNR  monoculture       Org
# 357    B2          1        WT_W_Org_1        WT_W  monoculture       Org
# 358    B2          2        WT_W_Org_2        WT_W  monoculture       Org
# 359    B2          3        WT_W_Org_3        WT_W  monoculture       Org
#
#     media  W  E  N  R genotype  A  K  P
# 0    Ctrl  0  0  0  0        A  1  0  0
# 1    Ctrl  0  0  0  0        A  1  0  0
# 2    Ctrl  0  0  0  0        A  1  0  0
# 3     ENR  0  1  1  1        A  1  0  0
# 4     ENR  0  1  1  1        A  1  0  0
# ..    ... .. .. .. ..      ... .. .. ..
# 355   WNR  1  0  1  1       WT  0  0  0
# 356   WNR  1  0  1  1       WT  0  0  0
# 357     W  1  0  0  0       WT  0  0  0
# 358     W  1  0  0  0       WT  0  0  0
# 359     W  1  0  0  0       WT  0  0  0
#
# [360 rows x 15 columns]

# %% [markdown]
# ## CellChat Follow-up
#
# Metadata columns:
# - batch
# - replicate
# - condition
# - culture
# - media
# - genotype
# - A
# - K
# - P

# %%
df = pd.read_csv("../ZenodoRepo/CellChat-Follow-up_all-cells.csv.zip")
metadata_columns = [
    "batch",
    "genotype",
    "media",
    "replicate",
    "culture",
    "condition",
    "A",
    "K",
    "P",
]
df_metadata = df.loc[:, metadata_columns]

# %%
df_metadata = df.loc[:, metadata_columns]
df_metadata = df_metadata.drop_duplicates(subset=['condition']).sort_values('condition').reset_index(drop=True)
df_metadata.to_csv("SampleDF_MC_CellChat.csv")
df_metadata
# Out:
#     batch genotype   media  replicate    culture       condition  A  K  P
# 0      B2      AKP    Ctrl          1   AKP_Ctrl   B2_AKP_Ctrl_1  1  1  1
# 1      B2      AKP    Ctrl          2   AKP_Ctrl   B2_AKP_Ctrl_2  1  1  1
# 2      B2      AKP    Ctrl          3   AKP_Ctrl   B2_AKP_Ctrl_3  1  1  1
# 3      B2      AKP     EGF          1    AKP_EGF    B2_AKP_EGF_1  1  1  1
# 4      B2      AKP     EGF          2    AKP_EGF    B2_AKP_EGF_2  1  1  1
# ..    ...      ...     ...        ...        ...             ... .. .. ..
# 199    B5       WT  SEMA3A          2  WT_SEMA3A  B5_WT_SEMA3A_2  0  0  0
# 200    B5       WT  SEMA3A          3  WT_SEMA3A  B5_WT_SEMA3A_3  0  0  0
# 201    B5       WT   WNT5A          1   WT_WNT5A   B5_WT_WNT5A_1  0  0  0
# 202    B5       WT   WNT5A          2   WT_WNT5A   B5_WT_WNT5A_2  0  0  0
# 203    B5       WT   WNT5A          3   WT_WNT5A   B5_WT_WNT5A_3  0  0  0
#
# [204 rows x 9 columns]

# %% [markdown]
# ## WNT-EGF Competition
#
# Metadata columns:
#
# - batch
# - treatment_1
# - reagent_1
# - concentration_1
# - treatment_2
# - reagent_2
# - concentration_2
# - replicate
# - culture
# - condition
# - WNT
# - WNT_Conc
# - EGF
# - EGF_Conc
# - WNT_EGF_Ratio
# - EGF_WNT_Ratio

# %%
df = pd.read_csv(
    "../ZenodoRepo/WNT-EGF-Competition_all-cells.csv.zip"
)
metadata_columns = [
    "batch",
    "treatment_1",
    "reagent_1",
    "concentration_1",
    "treatment_2",
    "reagent_2",
    "concentration_2",
    "replicate",
    "culture",
    "condition",
    "WNT",
    "WNT_Conc",
    "EGF",
    "EGF_Conc",
    "WNT_EGF_Ratio",
    "EGF_WNT_Ratio",
]
df_metadata = df.loc[:, metadata_columns]

# %%
df_metadata = df_metadata.drop_duplicates(subset=['condition']).sort_values('condition').reset_index(drop=True)
df_metadata.to_csv("SampleDF_MC_WNT-EGF.csv")
df_metadata
# Out:
#    batch treatment_1 reagent_1  concentration_1 treatment_2 reagent_2  \
# 0     B1      EGF-10       EGF               10       WNT-0       WNT
# 1     B1      EGF-10       EGF               10       WNT-0       WNT
# 2     B1      EGF-10       EGF               10       WNT-0       WNT
# 3     B1      EGF-25       EGF               25       WNT-0       WNT
# 4     B1      EGF-25       EGF               25       WNT-0       WNT
# 5     B1      EGF-25       EGF               25       WNT-0       WNT
# 6     B1      EGF-40       EGF               40       WNT-0       WNT
# 7     B1      EGF-40       EGF               40       WNT-0       WNT
# 8     B1      EGF-40       EGF               40       WNT-0       WNT
# 9     B1      EGF-50       EGF               50       WNT-0       WNT
# 10    B1      EGF-50       EGF               50       WNT-0       WNT
# 11    B1      EGF-50       EGF               50       WNT-0       WNT
# 12    B1      EGF-50       EGF               50      WNT-10       WNT
# 13    B1      EGF-50       EGF               50      WNT-10       WNT
# 14    B1      EGF-50       EGF               50      WNT-10       WNT
# 15    B1      EGF-50       EGF               50      WNT-20       WNT
# 16    B1      EGF-50       EGF               50      WNT-20       WNT
# 17    B1      EGF-50       EGF               50      WNT-20       WNT
# 18    B1      EGF-50       EGF               50      WNT-50       WNT
# 19    B1      EGF-50       EGF               50      WNT-50       WNT
# 20    B1      EGF-50       EGF               50      WNT-50       WNT
# 21    B1       WNT-0       WNT                0       EGF-0       EGF
# 22    B1       WNT-0       WNT                0       EGF-0       EGF
# 23    B1       WNT-0       WNT                0       EGF-0       EGF
# 24    B1     WNT-100       WNT              100       EGF-0       EGF
# 25    B1     WNT-100       WNT              100       EGF-0       EGF
# 26    B1     WNT-100       WNT              100       EGF-0       EGF
# 27    B1     WNT-100       WNT              100      EGF-10       EGF
# 28    B1     WNT-100       WNT              100      EGF-10       EGF
# 29    B1     WNT-100       WNT              100      EGF-10       EGF
# 30    B1     WNT-100       WNT              100      EGF-25       EGF
# 31    B1     WNT-100       WNT              100      EGF-25       EGF
# 32    B1     WNT-100       WNT              100      EGF-25       EGF
# 33    B1     WNT-100       WNT              100      EGF-40       EGF
# 34    B1     WNT-100       WNT              100      EGF-40       EGF
# 35    B1     WNT-100       WNT              100      EGF-40       EGF
# 36    B1     WNT-100       WNT              100      EGF-50       EGF
# 37    B1     WNT-100       WNT              100      EGF-50       EGF
# 38    B1     WNT-100       WNT              100      EGF-50       EGF
# 39    B1      WNT-10       WNT               10       EGF-0       EGF
# 40    B1      WNT-10       WNT               10       EGF-0       EGF
# 41    B1      WNT-10       WNT               10       EGF-0       EGF
# 42    B1      WNT-20       WNT               20       EGF-0       EGF
# 43    B1      WNT-20       WNT               20       EGF-0       EGF
# 44    B1      WNT-20       WNT               20       EGF-0       EGF
# 45    B1      WNT-20       WNT               20      EGF-10       EGF
# 46    B1      WNT-20       WNT               20      EGF-10       EGF
# 47    B1      WNT-20       WNT               20      EGF-10       EGF
# 48    B1      WNT-50       WNT               50       EGF-0       EGF
# 49    B1      WNT-50       WNT               50       EGF-0       EGF
# 50    B1      WNT-50       WNT               50       EGF-0       EGF
# 51    B1      WNT-50       WNT               50      EGF-25       EGF
# 52    B1      WNT-50       WNT               50      EGF-25       EGF
# 53    B1      WNT-50       WNT               50      EGF-25       EGF
#
#     concentration_2  replicate         culture         condition      WNT  \
# 0                 0          1    EGF-10_WNT-0    EGF-10_WNT-0_1    WNT-0
# 1                 0          2    EGF-10_WNT-0    EGF-10_WNT-0_2    WNT-0
# 2                 0          3    EGF-10_WNT-0    EGF-10_WNT-0_3    WNT-0
# 3                 0          1    EGF-25_WNT-0    EGF-25_WNT-0_1    WNT-0
# 4                 0          2    EGF-25_WNT-0    EGF-25_WNT-0_2    WNT-0
# 5                 0          3    EGF-25_WNT-0    EGF-25_WNT-0_3    WNT-0
# 6                 0          1    EGF-40_WNT-0    EGF-40_WNT-0_1    WNT-0
# 7                 0          2    EGF-40_WNT-0    EGF-40_WNT-0_2    WNT-0
# 8                 0          3    EGF-40_WNT-0    EGF-40_WNT-0_3    WNT-0
# 9                 0          1    EGF-50_WNT-0    EGF-50_WNT-0_1    WNT-0
# 10                0          2    EGF-50_WNT-0    EGF-50_WNT-0_2    WNT-0
# 11                0          3    EGF-50_WNT-0    EGF-50_WNT-0_3    WNT-0
# 12               10          1   EGF-50_WNT-10   EGF-50_WNT-10_1   WNT-10
# 13               10          2   EGF-50_WNT-10   EGF-50_WNT-10_2   WNT-10
# 14               10          3   EGF-50_WNT-10   EGF-50_WNT-10_3   WNT-10
# 15               20          1   EGF-50_WNT-20   EGF-50_WNT-20_1   WNT-20
# 16               20          2   EGF-50_WNT-20   EGF-50_WNT-20_2   WNT-20
# 17               20          3   EGF-50_WNT-20   EGF-50_WNT-20_3   WNT-20
# 18               50          1   EGF-50_WNT-50   EGF-50_WNT-50_1   WNT-50
# 19               50          2   EGF-50_WNT-50   EGF-50_WNT-50_2   WNT-50
# 20               50          3   EGF-50_WNT-50   EGF-50_WNT-50_3   WNT-50
# 21                0          1     WNT-0_EGF-0     WNT-0_EGF-0_1    WNT-0
# 22                0          2     WNT-0_EGF-0     WNT-0_EGF-0_2    WNT-0
# 23                0          3     WNT-0_EGF-0     WNT-0_EGF-0_3    WNT-0
# 24                0          1   WNT-100_EGF-0   WNT-100_EGF-0_1  WNT-100
# 25                0          2   WNT-100_EGF-0   WNT-100_EGF-0_2  WNT-100
# 26                0          3   WNT-100_EGF-0   WNT-100_EGF-0_3  WNT-100
# 27               10          1  WNT-100_EGF-10  WNT-100_EGF-10_1  WNT-100
# 28               10          2  WNT-100_EGF-10  WNT-100_EGF-10_2  WNT-100
# 29               10          3  WNT-100_EGF-10  WNT-100_EGF-10_3  WNT-100
# 30               25          1  WNT-100_EGF-25  WNT-100_EGF-25_1  WNT-100
# 31               25          2  WNT-100_EGF-25  WNT-100_EGF-25_2  WNT-100
# 32               25          3  WNT-100_EGF-25  WNT-100_EGF-25_3  WNT-100
# 33               40          1  WNT-100_EGF-40  WNT-100_EGF-40_1  WNT-100
# 34               40          2  WNT-100_EGF-40  WNT-100_EGF-40_2  WNT-100
# 35               40          3  WNT-100_EGF-40  WNT-100_EGF-40_3  WNT-100
# 36               50          1  WNT-100_EGF-50  WNT-100_EGF-50_1  WNT-100
# 37               50          2  WNT-100_EGF-50  WNT-100_EGF-50_2  WNT-100
# 38               50          3  WNT-100_EGF-50  WNT-100_EGF-50_3  WNT-100
# 39                0          1    WNT-10_EGF-0    WNT-10_EGF-0_1   WNT-10
# 40                0          2    WNT-10_EGF-0    WNT-10_EGF-0_2   WNT-10
# 41                0          3    WNT-10_EGF-0    WNT-10_EGF-0_3   WNT-10
# 42                0          1    WNT-20_EGF-0    WNT-20_EGF-0_1   WNT-20
# 43                0          2    WNT-20_EGF-0    WNT-20_EGF-0_2   WNT-20
# 44                0          3    WNT-20_EGF-0    WNT-20_EGF-0_3   WNT-20
# 45               10          1   WNT-20_EGF-10   WNT-20_EGF-10_1   WNT-20
# 46               10          2   WNT-20_EGF-10   WNT-20_EGF-10_2   WNT-20
# 47               10          3   WNT-20_EGF-10   WNT-20_EGF-10_3   WNT-20
# 48                0          1    WNT-50_EGF-0    WNT-50_EGF-0_1   WNT-50
# 49                0          2    WNT-50_EGF-0    WNT-50_EGF-0_2   WNT-50
# 50                0          3    WNT-50_EGF-0    WNT-50_EGF-0_3   WNT-50
# 51               25          1   WNT-50_EGF-25   WNT-50_EGF-25_1   WNT-50
# 52               25          2   WNT-50_EGF-25   WNT-50_EGF-25_2   WNT-50
# 53               25          3   WNT-50_EGF-25   WNT-50_EGF-25_3   WNT-50
#
#     WNT_Conc     EGF  EGF_Conc WNT_EGF_Ratio EGF_WNT_Ratio
# 0          0  EGF-10        10           0.0             -
# 1          0  EGF-10        10           0.0             -
# 2          0  EGF-10        10           0.0             -
# 3          0  EGF-25        25           0.0             -
# 4          0  EGF-25        25           0.0             -
# 5          0  EGF-25        25           0.0             -
# 6          0  EGF-40        40           0.0             -
# 7          0  EGF-40        40           0.0             -
# 8          0  EGF-40        40           0.0             -
# 9          0  EGF-50        50           0.0             -
# 10         0  EGF-50        50           0.0             -
# 11         0  EGF-50        50           0.0             -
# 12        10  EGF-50        50           0.2           5.0
# 13        10  EGF-50        50           0.2           5.0
# 14        10  EGF-50        50           0.2           5.0
# 15        20  EGF-50        50           0.4           2.5
# 16        20  EGF-50        50           0.4           2.5
# 17        20  EGF-50        50           0.4           2.5
# 18        50  EGF-50        50           1.0           1.0
# 19        50  EGF-50        50           1.0           1.0
# 20        50  EGF-50        50           1.0           1.0
# 21         0   EGF-0         0             -             -
# 22         0   EGF-0         0             -             -
# 23         0   EGF-0         0             -             -
# 24       100   EGF-0         0             -           0.0
# 25       100   EGF-0         0             -           0.0
# 26       100   EGF-0         0             -           0.0
# 27       100  EGF-10        10          10.0           0.1
# 28       100  EGF-10        10          10.0           0.1
# 29       100  EGF-10        10          10.0           0.1
# 30       100  EGF-25        25           4.0          0.25
# 31       100  EGF-25        25           4.0          0.25
# 32       100  EGF-25        25           4.0          0.25
# 33       100  EGF-40        40           2.5           0.4
# 34       100  EGF-40        40           2.5           0.4
# 35       100  EGF-40        40           2.5           0.4
# 36       100  EGF-50        50           2.0           0.5
# 37       100  EGF-50        50           2.0           0.5
# 38       100  EGF-50        50           2.0           0.5
# 39        10   EGF-0         0             -           0.0
# 40        10   EGF-0         0             -           0.0
# 41        10   EGF-0         0             -           0.0
# 42        20   EGF-0         0             -           0.0
# 43        20   EGF-0         0             -           0.0
# 44        20   EGF-0         0             -           0.0
# 45        20  EGF-10        10           2.0           0.5
# 46        20  EGF-10        10           2.0           0.5
# 47        20  EGF-10        10           2.0           0.5
# 48        50   EGF-0         0             -           0.0
# 49        50   EGF-0         0             -           0.0
# 50        50   EGF-0         0             -           0.0
# 51        50  EGF-25        25           2.0           0.5
# 52        50  EGF-25        25           2.0           0.5
# 53        50  EGF-25        25           2.0           0.5

# %% [markdown]
# ## Signal Perturbation
#
# Metadata columns:
#
# - batch
# - genotype
# - media
# - replicate
# - culture
# - condition
# - ligand
# - inhibitor
# - A
# - K

# %%
df = pd.read_csv(
    "../ZenodoRepo/Signal-Perturbation_all-cells.csv.zip"
)
metadata_columns = [
    "batch",
    "genotype",
    "media",
    "replicate",
    "culture",
    "condition",
    "ligand",
    "inhibitor",
    "A",
    "K",
]
df_metadata = df.loc[:, metadata_columns]

# %%
df_metadata = df_metadata.drop_duplicates(subset=['condition']).sort_values('condition').reset_index(drop=True)
df_metadata.to_csv("SampleDF_MC_Perturbation.csv")
df_metadata
# Out:
#     batch genotype             media  replicate              culture  \
# 0      B1       AK          Ctrl-CA3          1          AK_Ctrl-CA3
# 1      B1       AK          Ctrl-CA3          2          AK_Ctrl-CA3
# 2      B1       AK          Ctrl-CA3          3          AK_Ctrl-CA3
# 3      B1       AK    Ctrl-CHIR99021          1    AK_Ctrl-CHIR99021
# 4      B1       AK    Ctrl-CHIR99021          2    AK_Ctrl-CHIR99021
# ..    ...      ...               ...        ...                  ...
# 427    B1       WT        WNT3A-SIS3          2        WT_WNT3A-SIS3
# 428    B1       WT        WNT3A-SIS3          3        WT_WNT3A-SIS3
# 429    B1       WT  WNT3A-Trametinib          1  WT_WNT3A-Trametinib
# 430    B1       WT  WNT3A-Trametinib          2  WT_WNT3A-Trametinib
# 431    B1       WT  WNT3A-Trametinib          3  WT_WNT3A-Trametinib
#
#                     condition ligand   inhibitor  A  K
# 0            B1_AK_Ctrl-CA3_1   Ctrl         CA3  1  1
# 1            B1_AK_Ctrl-CA3_2   Ctrl         CA3  1  1
# 2            B1_AK_Ctrl-CA3_3   Ctrl         CA3  1  1
# 3      B1_AK_Ctrl-CHIR99021_1   Ctrl   CHIR99021  1  1
# 4      B1_AK_Ctrl-CHIR99021_2   Ctrl   CHIR99021  1  1
# ..                        ...    ...         ... .. ..
# 427        B1_WT_WNT3A-SIS3_2  WNT3A        SIS3  0  0
# 428        B1_WT_WNT3A-SIS3_3  WNT3A        SIS3  0  0
# 429  B1_WT_WNT3A-Trametinib_1  WNT3A  Trametinib  0  0
# 430  B1_WT_WNT3A-Trametinib_2  WNT3A  Trametinib  0  0
# 431  B1_WT_WNT3A-Trametinib_3  WNT3A  Trametinib  0  0
#
# [432 rows x 10 columns]
